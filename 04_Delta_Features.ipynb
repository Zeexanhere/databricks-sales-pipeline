# %%
# %sql
DESCRIBE HISTORY sales_db.silver_sales_orders

# %%
# %sql
SELECT * FROM sales_db.silver_sales_orders VERSION AS OF 0 LIMIT 5

# %%
# %sql
DESCRIBE DETAIL sales_db.silver_sales_orders

# %%
# %sql
OPTIMIZE sales_db.silver_sales_orders

# %%
# %sql
-- In production use 168 hours minimum
-- For learning, let's just do a dry run with safe retention
VACUUM sales_db.silver_sales_orders RETAIN 168 HOURS DRY RUN
